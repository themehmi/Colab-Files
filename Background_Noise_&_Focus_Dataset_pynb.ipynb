# %% [markdown]
# <a href="https://colab.research.google.com/github/themehmi/Colab-Files/blob/main/Background_Noise_%26_Focus_Dataset_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Handling**

# %%
import pandas as pd
import numpy as np
#fetch data from a url or csv
url=("https://raw.githubusercontent.com/themehmi/datasets/refs/heads/main/background_noise_focus_dataset.csv")
#printing dataset in form string data type to make it easier to understands
df=pd.read_csv(url)
df.head()
# Out:
#    participant_id  age           role task_type background_noise_type  \
# 0               1   44        Student   Writing         Traffic Noise
# 1               2   30        Student   Writing               Silence
# 2               3   23  Remote Worker   Reading               Silence
# 3               4   36   Professional   Writing     Songs with Lyrics
# 4               5   34  Remote Worker  Studying         Traffic Noise
#
#    noise_volume_level  focus_duration_minutes  perceived_focus_score  \
# 0                   8                      98                      5
# 1                   9                      31                      3
# 2                   4                      39                      9
# 3                   1                      93                      4
# 4                   1                      94                      6
#
#    task_completion_quality  mental_fatigue_after_task
# 0                        5                          1
# ...

# %%
print(df["age"].head())
# Out:
# 0    44
# 1    30
# 2    23
# 3    36
# 4    34
# Name: age, dtype: int64

# %%
#slicing
print(df["age"][30:40])
# Out:
# 30    19
# 31    40
# 32    29
# 33    24
# 34    41
# 35    17
# 36    35
# 37    43
# 38    22
# 39    23
# Name: age, dtype: int64

# %%
#conditional filtering
print(df["age"] [df["age"]>40])
# Out:
# 0      44
# 14     45
# 17     48
# 21     42
# 22     43
#        ..
# 489    47
# 494    43
# 496    43
# 497    41
# 499    43
# Name: age, Length: 143, dtype: int64
